# %%
import requests
import json
from pprint import pprint
from yaml import load, FullLoader

# %%
config_file = open('config.yaml', 'r')
config = load(config_file, Loader=FullLoader)

# %%
token = config['token']
headers = {'Authorization': 'OAuth ' + token}
API_URL = 'https://api-metrika.yandex.ru/stat/v1/data'
counter = '51583145'
startDate = '2018-12-01'
endDate = '2020-12-31'
dimensions = ['ym:s:date', 'ym:s:deviceCategory', 'ym:s:hasAdBlocker', 'ym:s:trafficSource']
metrics = ['ym:s:visits', 'ym:s:users', 'ym:s:pageviews']
metrics_string = ','.join(metrics)
dimensions_string = ','.join(dimensions)

# %%
def make_request(**kwargs):
    """Запрос к API Яндекс.Метрики. Возвращает JSON ответа"""
    return requests.get(API_URL, headers=headers, params = kwargs).json()

# %%
data = make_request(date1=startDate, date2=endDate, metrics=','.join(metrics), \
                    dimensions=','.join(dimensions), limit=100000, id=counter,  accuracy=1)

# %%
len(data['data'])
# Out:
# 7413

# %%
for line in data['data']:
    for dimensions_value in line['dimensions']:
        print(dimensions_value['name'])
    break
# Out:
# 2019-11-17
# Смартфоны
# Не определено
# Переходы по рекламе

# %%
report = []
for line in data['data']:
    dimension_list = [x['name'] for x in line['dimensions']]
    metrics_list = line['metrics']
    report.append(dimension_list + metrics_list)
    print(report)
    break
# Out:
# [['2019-11-17', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]]

# %%
def json_handler(data):
    """Преобразование ответа JSON в спикок листов"""
    report = []
    for line in data['data']:
        dimension_list = [x['name'] for x in line['dimensions']]
        metrics_list = line['metrics']
        report.append(dimension_list + metrics_list)
    return report

# %%
json_str = json.dumps(data['data'])
a_json_object = json.loads(json_str)
for i in enumerate(a_json_object):
    dimensions = [x['name'] for x in a_json_object[i[0]]['dimensions']]
    metrics = a_json_object[0]['metrics']
    print(dimensions + metrics)
# Out:
# ['2019-11-17', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-14', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-07', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-16', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-12', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-09', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-06', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-03', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-19', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-18', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-11', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-15', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-04', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-18', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-23', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-20', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-27', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-20', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-02', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-06', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-07', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-09', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-13', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-24', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-11', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-19', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-11', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-19', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-08', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-03', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-27', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-01', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-05', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-13', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-22', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-29', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-31', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-14', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-10', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-21', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-12', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-09', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-18', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-10', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-22', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-06', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-20', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-01', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-09', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-08', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-20', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-12', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-28', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-18', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-05', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-08', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-02', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-12-13', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-22', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-27', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-27', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-01', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-04', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-24', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-20', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-10', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-06', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-24', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-04', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-05', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-14', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-13', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-28', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-07', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-11', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-06', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-14', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-11', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-22', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-02', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-08', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-07', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-07', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-08', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-26', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-19', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-25', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-29', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-26', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-21', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-22', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-23', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-29', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-30', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-13', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-09', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-23', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-09', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-27', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-04', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-11', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-11', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-11', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-15', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-30', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-20', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-24', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-20', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-08', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-11', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-22', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-14', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-09', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-28', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-12', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-13', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2018-12-24', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-20', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-04', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-13', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-05', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-21', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-14', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-10', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-12', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-15', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-21', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-09', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-08-22', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-18', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-21', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-31', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-22', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-01', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-13', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-24', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-16', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-09-16', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-28', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-07', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-27', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-01', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-11', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-08', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-01-20', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-12', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-08-21', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-03', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-12', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-24', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-15', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-09-30', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-04', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-23', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-12', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-28', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-15', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-01-19', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2018-12-31', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-19', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-09', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-10', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-25', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-04', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-27', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-26', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-26', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-20', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-27', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-04', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-24', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-08', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-13', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-28', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-13', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-14', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-19', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-17', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2018-12-23', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2018-12-30', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-11', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-25', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-01', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-03', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-08-20', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-14', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-03-18', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-09-25', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2018-12-24', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-10', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-27', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-16', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-25', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2018-12-30', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-20', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-22', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-09', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-30', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-06', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-07', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-09-15', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-17', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-21', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-22', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-25', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-18', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-26', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-14', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-22', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-28', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-26', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-14', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-12-15', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-03-16', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-14', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-25', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-08', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-17', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-06', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-14', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-05', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-12-12', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-07-31', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-10-26', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-03', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-07', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2018-12-29', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-27', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-29', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-31', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-21', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-23', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-05', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-14', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-17', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-18', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-23', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-27', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-08', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-09', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-02', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-30', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-17', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2018-12-24', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2018-12-25', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2018-12-26', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-07', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-18', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-28', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-15', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-05', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-08', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-10', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-20', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-28', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-16', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-25', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-14', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-01', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-06', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-04-23', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-06-04', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-10-01', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-10-06', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-10-14', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-10-15', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2018-12-20', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-12', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-24', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-04', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-09', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-12', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-21', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-10', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-13', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-09', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-15', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-16', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-08', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-13', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-23', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-06-17', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-08-16', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-09', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-13', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-16', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-01-13', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-03-20', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-07-20', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-10-12', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-10-29', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-11', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2018-12-28', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2018-12-30', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-13', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-22', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-01', 'ПК', 'Не определено', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2019-03-15', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-26', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-07', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-17', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-16', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-03-02', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-03-10', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-03-23', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-05', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-06', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-06', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-09', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2018-12-23', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-02', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-09', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-15', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-17', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-24', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-26', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-26', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-02', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-19', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-28', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-15', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-16', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-25', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-08-23', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-03', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-12', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-16', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-28', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-08-14', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-09-17', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-10-31', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-02', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-10', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-09', 'Планшеты', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-18', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-20', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-28', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-14', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-21', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-07', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-09', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-10', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-02-20', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-03-19', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-03-21', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-10-09', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-10-13', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-10-16', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-10-19', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-10-22', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-01', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-25', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2018-12-25', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-10', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-27', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-14', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-05', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-07', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-21', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-07', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-08-13', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-08-25', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-14', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-16', 'Смартфоны', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2019-11-19', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-01-24', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-03-03', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-03-12', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-05-27', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-06-06', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-09-21', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-10', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-12', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-13', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-27', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-08', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2018-12-27', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-08', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-25', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-31', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-08', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-08', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-27', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-03', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-22', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-16', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-08-30', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-11', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-10', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-18', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-12-02', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-12-16', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-01-01', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-02-18', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-03-04', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-07-06', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-08-21', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-09-21', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-04', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-10', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2018-12-24', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-09', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-30', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-03', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-10', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-20', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-02', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-03', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-03', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-08', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-09', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-15', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-24', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-25', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-06-19', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-08-26', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-10', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-24', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-17', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-21', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-02-29', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-03-18', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-03-19', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-05-25', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-05-28', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-07-28', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-10-05', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-10-08', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-10-27', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-10-28', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-10-30', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-09', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-18', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-20', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-26', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-14', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2018-12-29', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-10', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-21', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-06', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-24', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-03', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-24', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-29', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-07', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-19', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-15', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-28', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-06-02', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-02', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-07', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-02', 'Смартфоны', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2019-11-04', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-15', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-18', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-12-12', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-12-14', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-03-13', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-05-15', 'ПК', 'Не определено', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-05-15', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-06-01', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-07-09', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-07-30', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-08-26', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-10-06', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-10-21', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-10-25', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-16', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-11', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2018-12-21', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2018-12-22', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-01', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-07', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-09', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-23', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-25', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-30', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-05', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-02-24', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-17', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-29', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-04', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-17', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-21', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-08-28', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-16', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-27', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-01-21', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-01-27', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-02-25', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-06-08', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-06-10', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-07-15', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-08-03', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-09-07', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-09-22', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-09-23', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-09-24', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-09-24', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-03', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-16', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-17', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2018-12-27', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-01-06', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-13', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-19', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-20', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-03-26', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-11', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-04-26', 'ПК', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-22', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-26', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-05-28', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-08-07', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-08-31', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-04', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-05', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-17', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-09-18', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-01', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-10-25', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-11-15', 'Смартфоны', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2019-12-09', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2019-12-16', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-01-16', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-02-26', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-03-20', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-04-24', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-04-25', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-04-27', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-05-19', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-06-02', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-07-14', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-07-23', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-07-29', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-08-04', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-08-10', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-08-13', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-08-17', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-09-08', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-09-18', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-09-30', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-10-07', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-10-23', 'ПК', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-10-24', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ...
# ['2020-10-30', 'ПК', 'Блокировщик используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-10-30', 'Планшеты', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-10-30', 'ТВ', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-10-31', 'ПК', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-10-31', 'ПК', 'Блокировщик используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-01', 'ПК', 'Блокировщик используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-01', 'ТВ', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-11-02', 'ПК', 'Не определено', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-11-02', 'ПК', 'Блокировщик не используется', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-11-02', 'ПК', 'Блокировщик не используется', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-11-03', 'ПК', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-11-03', 'ПК', 'Блокировщик используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-03', 'ПК', 'Блокировщик не используется', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-11-04', 'ПК', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-11-04', 'ПК', 'Блокировщик используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-04', 'Планшеты', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-05', 'ПК', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-11-05', 'ПК', 'Не определено', 'Переходы из поисковых систем', 338.0, 336.0, 457.0]
# ['2020-11-06', 'ПК', 'Не определено', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-11-06', 'ПК', 'Блокировщик не используется', 'Переходы из поисковых систем', 338.0, 336.0, 457.0]
# ['2020-11-06', 'Смартфоны', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-11-06', 'Планшеты', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-11-07', 'ПК', 'Не определено', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-11-07', 'ПК', 'Блокировщик используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-07', 'ПК', 'Блокировщик не используется', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-11-07', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-09', 'ПК', 'Блокировщик не используется', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-11-09', 'Смартфоны', 'Не определено', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-11-09', 'Смартфоны', 'Не определено', 'Переходы по ссылкам на сайтах', 338.0, 336.0, 457.0]
# ['2020-11-09', 'Смартфоны', 'Блокировщик не используется', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-11-09', 'Планшеты', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-11-10', 'ПК', 'Блокировщик не используется', 'Переходы из поисковых систем', 338.0, 336.0, 457.0]
# ['2020-11-10', 'Планшеты', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-11', 'Смартфоны', 'Блокировщик не используется', 'Переходы из поисковых систем', 338.0, 336.0, 457.0]
# ['2020-11-11', 'Планшеты', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-11-11', 'Планшеты', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-12', 'ПК', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-11-12', 'Планшеты', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-13', 'ПК', 'Блокировщик используется', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-11-13', 'ПК', 'Блокировщик используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-13', 'Смартфоны', 'Не определено', 'Переходы из поисковых систем', 338.0, 336.0, 457.0]
# ['2020-11-13', 'Планшеты', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-14', 'ПК', 'Блокировщик используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-14', 'Планшеты', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-15', 'Планшеты', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-11-18', 'ПК', 'Блокировщик используется', 'Переходы из поисковых систем', 338.0, 336.0, 457.0]
# ['2020-11-18', 'ПК', 'Блокировщик используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-18', 'Смартфоны', 'Не определено', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-11-18', 'Планшеты', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-11-18', 'Планшеты', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-19', 'ПК', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-11-19', 'ПК', 'Не определено', 'Переходы по ссылкам на сайтах', 338.0, 336.0, 457.0]
# ['2020-11-19', 'ПК', 'Блокировщик не используется', 'Переходы из поисковых систем', 338.0, 336.0, 457.0]
# ['2020-11-20', 'ПК', 'Не определено', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-11-20', 'ПК', 'Блокировщик не используется', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-11-20', 'ПК', 'Блокировщик не используется', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-11-20', 'ПК', 'Блокировщик не используется', 'Переходы по ссылкам на сайтах', 338.0, 336.0, 457.0]
# ['2020-11-20', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-21', 'ПК', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-11-21', 'ПК', 'Блокировщик используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-21', 'Смартфоны', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-11-21', 'Планшеты', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-22', 'Смартфоны', 'Не определено', 'Переходы из поисковых систем', 338.0, 336.0, 457.0]
# ['2020-11-22', 'Смартфоны', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-23', 'ПК', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-11-23', 'ПК', 'Не определено', 'Переходы по ссылкам на сайтах', 338.0, 336.0, 457.0]
# ['2020-11-23', 'ПК', 'Не определено', 'Переходы из поисковых систем', 338.0, 336.0, 457.0]
# ['2020-11-23', 'ПК', 'Блокировщик не используется', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-11-23', 'Планшеты', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-23', 'Планшеты', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-24', 'ПК', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-11-25', 'ПК', 'Блокировщик используется', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-11-25', 'ПК', 'Блокировщик используется', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-11-26', 'ПК', 'Не определено', 'Переходы из поисковых систем', 338.0, 336.0, 457.0]
# ['2020-11-26', 'Смартфоны', 'Не определено', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-11-26', 'Смартфоны', 'Блокировщик не используется', 'Переходы из поисковых систем', 338.0, 336.0, 457.0]
# ['2020-11-26', 'Планшеты', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-26', 'Планшеты', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-27', 'ПК', 'Блокировщик используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-27', 'ПК', 'Блокировщик не используется', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-11-27', 'Смартфоны', 'Блокировщик не используется', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-11-27', 'Планшеты', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-11-27', 'Планшеты', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-28', 'ПК', 'Блокировщик не используется', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-11-28', 'Планшеты', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-11-28', 'Планшеты', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-29', 'ПК', 'Блокировщик не используется', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-11-29', 'ПК', 'Блокировщик не используется', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-11-29', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-30', 'ПК', 'Не определено', 'Переходы по ссылкам на сайтах', 338.0, 336.0, 457.0]
# ['2020-11-30', 'ПК', 'Блокировщик используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-11-30', 'ПК', 'Блокировщик не используется', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-11-30', 'ПК', 'Блокировщик не используется', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-11-30', 'Планшеты', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-01', 'ПК', 'Не определено', 'Переходы по ссылкам на сайтах', 338.0, 336.0, 457.0]
# ['2020-12-01', 'ПК', 'Блокировщик не используется', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-12-01', 'Планшеты', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-12-01', 'Планшеты', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-02', 'ПК', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-12-02', 'ПК', 'Не определено', 'Переходы по ссылкам на сайтах', 338.0, 336.0, 457.0]
# ['2020-12-02', 'ПК', 'Блокировщик используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-02', 'ПК', 'Блокировщик не используется', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-12-02', 'ПК', 'Блокировщик не используется', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-12-02', 'Смартфоны', 'Не определено', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-12-02', 'Планшеты', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-03', 'ПК', 'Не определено', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-12-03', 'ПК', 'Блокировщик используется', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-12-03', 'ПК', 'Блокировщик используется', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-12-03', 'Смартфоны', 'Блокировщик не используется', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-12-04', 'ПК', 'Блокировщик используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-04', 'ПК', 'Блокировщик не используется', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-12-04', 'Планшеты', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-05', 'ПК', 'Блокировщик используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-05', 'ПК', 'Блокировщик не используется', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-12-05', 'ПК', 'Блокировщик не используется', 'Переходы из поисковых систем', 338.0, 336.0, 457.0]
# ['2020-12-05', 'Смартфоны', 'Не определено', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-12-05', 'Планшеты', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-05', 'Планшеты', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-06', 'ПК', 'Блокировщик используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-06', 'Смартфоны', 'Не определено', 'Переходы из поисковых систем', 338.0, 336.0, 457.0]
# ['2020-12-06', 'Планшеты', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-07', 'ПК', 'Не определено', 'Переходы из поисковых систем', 338.0, 336.0, 457.0]
# ['2020-12-07', 'ПК', 'Блокировщик не используется', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-12-07', 'ПК', 'Блокировщик не используется', 'Переходы из поисковых систем', 338.0, 336.0, 457.0]
# ['2020-12-07', 'Смартфоны', 'Блокировщик не используется', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-12-07', 'Планшеты', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-07', 'Планшеты', 'Блокировщик не используется', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-12-07', 'Планшеты', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-08', 'ПК', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-12-08', 'ПК', 'Не определено', 'Переходы из поисковых систем', 338.0, 336.0, 457.0]
# ['2020-12-08', 'Смартфоны', 'Не определено', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-12-08', 'Планшеты', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-09', 'ПК', 'Не определено', 'Переходы из поисковых систем', 338.0, 336.0, 457.0]
# ['2020-12-09', 'ПК', 'Блокировщик не используется', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-12-09', 'ПК', 'Блокировщик не используется', 'Переходы из поисковых систем', 338.0, 336.0, 457.0]
# ['2020-12-09', 'Смартфоны', 'Не определено', 'Переходы из поисковых систем', 338.0, 336.0, 457.0]
# ['2020-12-09', 'Планшеты', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-12-09', 'Планшеты', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-10', 'ПК', 'Не определено', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-12-10', 'ПК', 'Не определено', 'Переходы из поисковых систем', 338.0, 336.0, 457.0]
# ['2020-12-10', 'ПК', 'Блокировщик не используется', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-12-10', 'Смартфоны', 'Не определено', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-12-10', 'Планшеты', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-12-11', 'ПК', 'Не определено', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-12-11', 'ПК', 'Не определено', 'Переходы из поисковых систем', 338.0, 336.0, 457.0]
# ['2020-12-11', 'ПК', 'Блокировщик используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-11', 'ПК', 'Блокировщик не используется', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-12-11', 'ПК', 'Блокировщик не используется', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-12-11', 'Смартфоны', 'Блокировщик не используется', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-12-12', 'ПК', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-12-12', 'ПК', 'Не определено', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-12-13', 'ПК', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-12-13', 'ПК', 'Блокировщик используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-13', 'Смартфоны', 'Не определено', 'Переходы из поисковых систем', 338.0, 336.0, 457.0]
# ['2020-12-13', 'Планшеты', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-12-14', 'ПК', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-12-14', 'ПК', 'Не определено', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-12-14', 'ПК', 'Блокировщик используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-14', 'Смартфоны', 'Блокировщик не используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-15', 'ПК', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-12-15', 'ПК', 'Блокировщик используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-15', 'ПК', 'Блокировщик не используется', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-12-15', 'ПК', 'Блокировщик не используется', 'Переходы из поисковых систем', 338.0, 336.0, 457.0]
# ['2020-12-15', 'Смартфоны', 'Блокировщик не используется', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-12-15', 'Планшеты', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-12-16', 'ПК', 'Не определено', 'Переходы по ссылкам на сайтах', 338.0, 336.0, 457.0]
# ['2020-12-16', 'ПК', 'Блокировщик не используется', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-12-16', 'Смартфоны', 'Не определено', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-12-17', 'Планшеты', 'Не определено', 'Внутренние переходы', 338.0, 336.0, 457.0]
# ['2020-12-17', 'Планшеты', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-18', 'ПК', 'Не определено', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-12-18', 'ПК', 'Блокировщик используется', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-18', 'ПК', 'Блокировщик не используется', 'Прямые заходы', 338.0, 336.0, 457.0]
# ['2020-12-18', 'Планшеты', 'Не определено', 'Переходы по рекламе', 338.0, 336.0, 457.0]
# ['2020-12-19', 'ПК', 'Не определено', 'Прямые заходы', 338.0, 336.0, 457.0]

# %%
rep = json_handler(data)
rating_dict = {
    'Переходы из поисковых систем': 0,
    'Переходы из социальных сетей': 0,
    'Внутренние переходы': 0,
    'Переходы по рекламе': 0,
    'Переходы по ссылкам на сайтах': 0,
    'Прямые заходы': 0,
}

for line in rep:
    if line[3] == 'Переходы по рекламе' and line[2] == 'Блокировщик используется':
        rating_dict['Переходы по рекламе'] += 1
    elif line[3] == 'Переходы из поисковых систем' and line[2] == 'Блокировщик используется':
        rating_dict['Переходы из поисковых систем'] += 1
    elif line[3] == 'Переходы из социальных сетей' and line[2] == 'Блокировщик используется':
        rating_dict['Переходы из социальных сетей'] += 1
    elif line[3] == 'Внутренние переходы' and line[2] == 'Блокировщик используется':
        rating_dict['Внутренние переходы'] += 1
    elif line[3] == 'Переходы по ссылкам на сайтах' and line[2] == 'Блокировщик используется':
        rating_dict['Переходы по ссылкам на сайтах'] += 1
    elif line[3] == 'Прямые заходы' and line[2] == 'Блокировщик используется':
        rating_dict['Прямые заходы'] += 1
print(rating_dict)
# Out:
# {'Переходы из поисковых систем': 20, 'Переходы из социальных сетей': 1, 'Внутренние переходы': 71, 'Переходы по рекламе': 542, 'Переходы по ссылкам на сайтах': 5, 'Прямые заходы': 54}

# %%
list_rating = list(rating_dict.items())

# %%
print(list_rating)
# Out:
# [('Переходы из поисковых систем', 20), ('Переходы из социальных сетей', 1), ('Внутренние переходы', 71), ('Переходы по рекламе', 542), ('Переходы по ссылкам на сайтах', 5), ('Прямые заходы', 54)]

# %%
list_rating.sort(key=lambda i: i[1])

# %%
list_rating
# Out:
# [('Переходы из социальных сетей', 1),
#  ('Переходы по ссылкам на сайтах', 5),
#  ('Переходы из поисковых систем', 20),
#  ('Прямые заходы', 54),
#  ('Внутренние переходы', 71),
#  ('Переходы по рекламе', 542)]
